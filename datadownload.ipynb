# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Downloading NVIDIA stock prices for the last 365 days
nvidia = yf.download('NVDA', start='2000-03-22', end='2024-04-07')
# Downloading S&P 500 index data for the last 365 days
sp500 = yf.download('^GSPC', start='2000-03-22', end='2024-04-07')

# Dowlonad the data for Meta, Microsoft, Alphabet, Amazon, Apple and Tesla

meta = yf.download('META', start='2000-03-22', end='2024-04-07')
microsoft = yf.download('MSFT', start='2000-03-22', end='2024-04-07')
alphabet = yf.download('GOOGL', start='2000-03-22', end='2024-04-07')
amazon = yf.download('AMZN', start='2000-03-22', end='2024-04-07')
apple = yf.download('AAPL', start='2000-03-22', end='2024-04-07')
tesla = yf.download('TSLA', start='2000-03-22', end='2024-04-07')

# Plotting the data
plt.plot(nvidia['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('NVIDIA Stock Price')
plt.show()

# Plotting the data
plt.plot(sp500['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('S&P 500 Index')
plt.show()


# Plotting the data
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Bitcoin Price')
plt.show()

# Plotting the data
plt.plot(meta['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Meta Stock Price')
plt.show()

# Plotting the data
plt.plot(microsoft['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Microsoft Stock Price')
plt.show()

# Plotting the data

plt.plot(alphabet['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Alphabet Stock Price')
plt.show()

# Plotting the data

plt.plot(amazon['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Amazon Stock Price')
plt.show()

# Plotting the data

plt.plot(apple['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Apple Stock Price')
plt.show()

# Plotting the data

plt.plot(tesla['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Tesla Stock Price')
plt.show()

# Saving the data to a CSV file
nvidia.to_csv('nvidia.csv')

# Saving the data to a CSV file
sp500.to_csv('sp500.csv')


# Saving the data to a CSV file

meta.to_csv('meta.csv')

# Saving the data to a CSV file

microsoft.to_csv('microsoft.csv')

# Saving the data to a CSV file

alphabet.to_csv('alphabet.csv')

# Saving the data to a CSV file

amazon.to_csv('amazon.csv')

# Saving the data to a CSV file

apple.to_csv('apple.csv')

# Saving the data to a CSV file

tesla.to_csv('tesla.csv')




# Reading the data from the CSV file
df_bitcoin = pd.read_csv('bitcoin.csv')
print(df_bitcoin)

# Reading the data from the CSV file
df = pd.read_csv('nvidia.csv')
print(df)

# Reading the data from the CSV file
df_sp500 = pd.read_csv('sp500.csv')
print(df_sp500)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# ...
